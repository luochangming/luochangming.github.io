# %%
import requests #用於API HTTP requests
import pandas as pd


def amap_api_search_by_keyword_city_code(kw, cc, api_key):

    parameters = {'key': api_key}  # 高德地图API 获取Key
    parameters.update( {'keywords': kw,
                        'city':     cc,
                        'citylimit': True
                       } )

    pois = []   # 建构最终结果列表pois
    pg_no = 1   # 建构pg_no，每次给不一样的可选参数page值

    while True: # 不断迭代，直到 break跳出
        parameters.update({'page':pg_no})  #建构可选参数page值 为 pg_no

        r = requests.get ("http://restapi.amap.com/v3/place/text", params=parameters)
        data = r.json()

        pois.extend(data['pois'])         # 使用Python列表之extend方法，把返回数据中的结果data['pois']存入pois


        no_pois_this_search = len(pois)   # 计算 累积实质结果数
        no_pois = int(data['count'])      # 计算 应有的实质数量


        if (no_pois_this_search >= no_pois):  # 若 累积实质结果数 >= 应有的实质数量
            break                                   # 则结束迭代跳出
        else:
            pg_no +=1                               # 否则找下一页数据，把 pg_no增1


    # 使用pandas 模块处理数据
    df_input = pd.DataFrame(pois)

    # 选择部份栏位准备输出
    select_fields = "location	address	adname	cityname	id	importance	name	pname	tel	type	typecode".split("\t")
    df = df_input[select_fields]

    # 经纬度 增加新栏位字段
    df = df.assign( 经 = [x.split(',')[0] for x in df['location']])
    df = df.assign( 纬 = [x.split(',')[1] for x in df['location']])
    df = df.assign(keywords = [kw]*len(df['location']))

    
    # 使用 return返回
    return(df)

# %%
 keywords_fields = "欢乐世界	海底世界	主题公园	旋转木马".split("\t")

# %%
g_list=[]

for y in  keywords_fields:
    z=amap_api_search_by_keyword_city_code(y, '中国', '2f4c20ac232c4458b8656d711f0a7d08')
   
    g_list.append(z)

# %%
df=pd.concat(g_list)

# %%
df
# Out:
#                  location                           address adname  \
# 0    104.715296,31.784053                        太白西路西山公园山顶    江油市
# 1    120.543715,31.841407                    杨舍镇湖滨南路暨阳湖生态园内   张家港市
# 2    108.975122,32.709362                         高新区秦岭大道2号    汉滨区
# 3    106.509310,29.504526                           西郊路35附近   九龙坡区
# 4    113.306984,23.137483                     先烈中路120广州动物园内    越秀区
# 5    116.496399,39.869064                     东四环小武基北路北京欢乐谷    朝阳区
# 6    126.527729,43.861151                          中东城市广场3楼    船营区
# 7    120.538760,31.840570                           杨舍镇南二环路   张家港市
# 8    125.330894,43.880893                    民康路树勋街249号儿童公园    南关区
# 9    110.004891,39.812725       达拉特北路与达拉特南路交叉口东北150米北国新天地附近    东胜区
# 10   108.976913,32.709328                        9路;11路;22路    汉滨区
# 11   117.515900,30.649076                                8路    贵池区
# 12   113.332909,23.002594      大石镇番禺大道与汉溪大道交口长隆旅游度假村内长隆欢乐世界    番禺区
# 13   118.886917,42.269343                            海贝尔游乐城    松山区
# 14   114.126637,22.546401                        湖贝路2014号附近    罗湖区
# 15   101.724604,26.578028                         东区湖光东街41号     东区
# 16   121.564467,31.152736                       北蔡镇沪南路2472号   浦东新区
# 473  湘西土家族苗族自治州  B02E70MJGK         []                 幸福树婚庆      湖南省
# 474         盘锦市  B0FFHDLD21         []             爆米花儿童美发乐园      辽宁省
# 475         韶关市  B0FFFPIKMN         []               金年华美容会所      广东省
# 476         苏州市  B0FFG9V6H1         []        红黄蓝亲子园江苏苏州张家港园      江苏省
# 477         杭州市  B0FFHJTGLF         []      李氏皇家经典婚纱摄影(彩虹大道)      浙江省
# 478         郑州市  B0FFFX7M7I         []                  闺蜜美甲      河南省
# 479         郑州市  B0FFG7DQZ3         []               伊靓轩美甲美睫      河南省
# 480         运城市  B0FFI8ZN8G         []               指尖缘美甲美睫      山西省
# 481         襄阳市  B0FFGIDG1O         []                  女神酒庄      湖北省
# 482         运城市  B0FFGRPTNF         []          瑞倪维儿美容(飞云南路)      山西省
# 483         临沂市  B0FFFEHGZB         []                  乐界酒吧      山东省
# 484         开封市  B0FFG2IW06         []                杰作刺青纹身      河南省
# 485         成都市  B0FFHE6YJR         []                  MiNi      四川省
# 486         常州市  B0FFIA7K6V         []        天津纹身艺术馆(常州旗舰店)      江苏省
# 487         临沂市  B0FFGYEA2G         []                  鑫宇装饰      山东省
# 488         长沙市  B0FFHZT5CJ         []   开心岛婴幼儿游泳馆(星沙华润万象汇店)      湖南省
# 489         桂林市  B0FFHX72C2         []  康淳胶美甲美睫用品体验服务中心(万达店)  广西壮族自治区
# 490         邵阳市  B02E30P8B8         []                   三V吧      湖南省
# 491         运城市  B0FFHVMT7E         []              诗和远方小妮花艺      山西省
# 492         襄阳市  B0FFH37M14         []                唯舞国际舞蹈      湖北省
# 493         襄阳市  B0FFGIDIC6         []         可诺丹婷美颜美体(枣阳店)      湖北省
# 494         苏州市  B0FFI2KO4T         []   东方童画少儿美术(太仓万达金街体验馆)      江苏省
# 495        连云港市  B0FFFXJTJO         []                    金苑      江苏省
# 496         潍坊市  B0FFH6XSY6         []    柠檬家可爱可亲母婴生活馆(加菲猫店)      山东省
# 497         益阳市  B0FFFF7TL3         []           I Like It寿司      湖南省
# 498         安阳市  B0FFFZT6A0         []      微笑宝贝专业儿童摄影·益智游泳馆      河南省
# 499         镇江市  B0FFHZ6LAP         []                   溜溜族      江苏省
# 500         成都市  B0FFIDABLR         []              屈臣氏(简阳店)      四川省
#
#                              tel                      type typecode  \
# 0                   0816-3599255           体育休闲服务;休闲场所;游乐场   080501
# 1    0512-35023003;0512-35023000           体育休闲服务;休闲场所;游乐场   080501
# 2                   0915-2391666           体育休闲服务;休闲场所;游乐场   080501
# 3                             []           体育休闲服务;休闲场所;游乐场   080501
# 4                             []           体育休闲服务;休闲场所;游乐场   080501
# 5                             []           体育休闲服务;休闲场所;游乐场   080501
# 6                             []           体育休闲服务;休闲场所;游乐场   080501
# 7                             []           体育休闲服务;休闲场所;游乐场   080501
# 8                             []           体育休闲服务;休闲场所;游乐场   080501
# 9                             []           体育休闲服务;休闲场所;游乐场   080501
# 10                            []        交通设施服务;公交车站;公交车站相关   150700
# 11                            []        交通设施服务;公交车站;公交车站相关   150700
# 12                            []            通行设施;临街院门;临街院门   991400
# 13                            []           体育休闲服务;娱乐场所;游戏厅   080305
# 14   0755-82259802;0755-82207133             体育休闲服务;影剧院;剧场   080603
# 15                  0812-3885777  体育休闲服务;体育休闲服务场所;体育休闲服务场所   080000
# 16                            []  体育休闲服务;体育休闲服务场所;体育休闲服务场所   080000
# 17                            []           体育休闲服务;休闲场所;游乐场   080501
# 18                            []  体育休闲服务;体育休闲服务场所;体育休闲服务场所   080000
# 19                            []           体育休闲服务;休闲场所;游乐场   080501
# 20      0435-3578123;15943506867           体育休闲服务;休闲场所;游乐场   080501
# 21                            []  体育休闲服务;体育休闲服务场所;体育休闲服务场所   080000
# 22                            []           体育休闲服务;娱乐场所;游戏厅   080305
# 23                  0911-8066592           体育休闲服务;休闲场所;游乐场   080501
# 24                            []        购物服务;购物相关场所;购物相关场所   060000
# 25                            []          体育休闲服务;娱乐场所;娱乐场所   080300
# 26                            []            生活服务;维修站点;维修站点   071200
# 27                            []            通行设施;临街院门;临街院门   991400
# 28                   15922488669           体育休闲服务;休闲场所;游乐场   080501
# 29                            []           体育休闲服务;休闲场所;游乐场   080501
# ..                           ...                       ...      ...
# 471                0755-23306119          生活服务;美容美发店;美容美发店   071100
# 472    0514-83915985;18052589985          科教文化服务;培训机构;培训机构   141400
# 473                 0743-8231232        生活服务;生活服务场所;生活服务场所   070000
# 474                           []        生活服务;生活服务场所;生活服务场所   070000
# 475                  13826328161          生活服务;美容美发店;美容美发店   071100
# 476                0512-56313833           体育休闲服务;休闲场所;游乐场   080501
# 477                           []           生活服务;摄影冲印店;摄影冲印   071300
# 478                  15838139983          生活服务;美容美发店;美容美发店   071100
# 479                  13598811171          生活服务;美容美发店;美容美发店   071100
# 480                  15340988911          生活服务;美容美发店;美容美发店   071100
# 481                  18062800888            购物服务;专卖店;烟酒专卖店   061210
# 482      15935991844;15035067692          生活服务;美容美发店;美容美发店   071100
# 483                  18305396869            体育休闲服务;娱乐场所;酒吧   080304
# 484                  18537827755          生活服务;美容美发店;美容美发店   071100
# 485                  18096385151            购物服务;专卖店;儿童用品店   061207
# 486                  13912348181        生活服务;生活服务场所;生活服务场所   070000
# 487                           []        生活服务;生活服务场所;生活服务场所   070000
# 488                0731-86806786         生活服务;婴儿服务场所;婴儿游泳馆   072001
# 489                  18877359857          生活服务;美容美发店;美容美发店   071100
# 490                           []            体育休闲服务;娱乐场所;酒吧   080304
# 491                  18295712027          购物服务;花鸟鱼虫市场;花卉市场   060501
# 492                 0710-6636366          科教文化服务;培训机构;培训机构   141400
# 493                           []          生活服务;美容美发店;美容美发店   071100
# 494                0512-33001771        生活服务;生活服务场所;生活服务场所   070000
# 495                           []      购物服务;服装鞋帽皮具店;服装鞋帽皮具店   061100
# 496                  18506456220            购物服务;专卖店;儿童用品店   061207
# 497                  15898404315            餐饮服务;外国餐厅;日本料理   050202
# 498                           []        生活服务;婴儿服务场所;婴儿服务场所   072000
# 499                  18952948441           体育休闲服务;运动场馆;溜冰场   080107
# 500                 028-27210339             购物服务;超级市场;屈臣氏   060411
#
#               经          纬 keywords
# 0    104.715296  31.784053     欢乐世界
# 1    120.543715  31.841407     欢乐世界
# 2    108.975122  32.709362     欢乐世界
# 3    106.509310  29.504526     欢乐世界
# 4    113.306984  23.137483     欢乐世界
# 5    116.496399  39.869064     欢乐世界
# 6    126.527729  43.861151     欢乐世界
# 7    120.538760  31.840570     欢乐世界
# 8    125.330894  43.880893     欢乐世界
# 9    110.004891  39.812725     欢乐世界
# 10   108.976913  32.709328     欢乐世界
# 11   117.515900  30.649076     欢乐世界
# 12   113.332909  23.002594     欢乐世界
# 13   118.886917  42.269343     欢乐世界
# 14   114.126637  22.546401     欢乐世界
# 15   101.724604  26.578028     欢乐世界
# 16   121.564467  31.152736     欢乐世界
# 17   119.390535  26.247443     欢乐世界
# 18   112.205405  31.069995     欢乐世界
# 19   110.850861  21.678246     欢乐世界
# 20   125.934577  41.706787     欢乐世界
# 21   112.917179  28.086101     欢乐世界
# 22   125.395076  43.859538     欢乐世界
# 23   109.438366  36.621465     欢乐世界
# 24   129.617200  44.581519     欢乐世界
# 25   113.749592  22.782176     欢乐世界
# 26   118.001208  37.381216     欢乐世界
# 27   120.613607  32.339645     欢乐世界
# 28   116.963748  33.665166     欢乐世界
# 29   120.761913  30.828843     欢乐世界
# ..          ...        ...      ...
# 471  114.047320  22.596650     旋转木马
# 472  119.180742  32.273999     旋转木马
# 473  109.741560  28.312473     旋转木马
# 474  122.075148  41.124448     旋转木马
# 475  113.599914  24.807957     旋转木马
# 476  120.516562  31.870246     旋转木马
# 477  120.265070  30.170424     旋转木马
# 478  113.311551  34.806375     旋转木马
# 479  113.302512  34.797761     旋转木马
# 480  110.849952  35.417331     旋转木马
# 481  112.761628  32.120087     旋转木马
# 482  110.835878  35.407946     旋转木马
# 483  118.624565  35.784527     旋转木马
# 484  114.464879  34.478340     旋转木马
# 485  104.549036  30.391895     旋转木马
# 486  119.953136  31.775962     旋转木马
# 487  118.626305  35.785583     旋转木马
# 488  113.086612  28.248856     旋转木马
# 489  110.319652  25.243384     旋转木马
# 490  110.635640  26.727554     旋转木马
# 491  110.850404  35.417259     旋转木马
# 492  112.760828  32.120318     旋转木马
# 493  112.761432  32.120100     旋转木马
# 494  121.138636  31.460234     旋转木马
# 495  119.130088  34.837801     旋转木马
# 496  118.828924  36.851020     旋转木马
# 497  112.361421  28.841405     旋转木马
# 498  114.541944  35.537344     旋转木马
# 499  119.438954  32.196683     旋转木马
# 500  103.509590  30.195042     旋转木马
#
# [3080 rows x 14 columns]

# %%
df.to_csv('data2.tsv',encoding='utf8',sep='\t')
